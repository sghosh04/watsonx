# %% [markdown]
# # How to perform inference using Generative AI Foundation Models deployed as prompt templates in IBM watsonx, AI and Data platform
#
# #### Author: Shuvanker Ghosh, IBM Technology Expert Labs, sghosh@us.ibm.com
#
# #### This notebook demonstrate how to automate the inference using Generative AI Foundation Model deployed as prompt template in IBM watsonx in order to infuse the usage of the model in business applications and workflows

# %% [markdown]
# ## Setup packages and the runtime

# %% [markdown]
# ### Setup packages

# %%
# Install ibm-watson-machine-learning python package
# !pip install -U ibm-watson-machine-learning
# Out:
# Requirement already satisfied: ibm-watson-machine-learning in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (1.0.338)
# Collecting ibm-watson-machine-learning
#   Downloading ibm_watson_machine_learning-1.0.339-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (2.31.0)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (1.26.18)
# Requirement already satisfied: pandas<1.6.0,>=0.24.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (1.5.3)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (2023.11.17)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (0.8.10)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (23.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (6.0.0)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-watson-machine-learning) (2.12.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.12.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.12.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.12.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.10.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from ibm-cos-sdk-core==2.12.0->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas<1.6.0,>=0.24.2->ibm-watson-machine-learning) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from pandas<1.6.0,>=0.24.2->ibm-watson-machine-learning) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests->ibm-watson-machine-learning) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from requests->ibm-watson-machine-learning) (3.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from importlib-metadata->ibm-watson-machine-learning) (3.11.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python-RT23.1/lib/python3.10/site-packages (from lomond->ibm-watson-machine-learning) (1.16.0)
# Downloading ibm_watson_machine_learning-1.0.339-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.4 MB/s eta 0:00:00
# Installing collected packages: ibm-watson-machine-learning
#   Attempting uninstall: ibm-watson-machine-learning
#     Found existing installation: ibm-watson-machine-learning 1.0.338
#     Uninstalling ibm-watson-machine-learning-1.0.338:
#       Successfully uninstalled ibm-watson-machine-learning-1.0.338
# Successfully installed ibm-watson-machine-learning-1.0.339

# %%
# Import necessary packages
import requests, json, logging
from ibm_watson_machine_learning import APIClient

# %%
# Setup logging
import sys
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')
logger = logging.getLogger()

# %% [markdown]
# ### Getting IBM Cloud API Key and Location of Waston Machine Learning in IBM Cloud
#
# Authenticate the Watson Machine Learning service on IBM Cloud. You need to provide platform `apikey` and instance `location`.
#
# You can use [IBM Cloud CLI](https://cloud.ibm.com/docs/cli/index.html) to retrieve platform API Key and instance location.
#
# API Key can be generated in the following way:
# ```
# ibmcloud login
# ibmcloud iam api-key-create API_KEY_NAME
# ```
#
# In result, get the value of `api_key` from the output.
#
#
# Location of your WML instance can be retrieved in the following way:
# ```
# ibmcloud login --apikey API_KEY -a https://cloud.ibm.com
# ibmcloud resource service-instance WML_INSTANCE_NAME
# ```
#
# In result, get the value of `location` from the output.
#
# **Tip**: Your `Cloud API key` can be generated by going to the [**Users** section of the Cloud console](https://cloud.ibm.com/iam#/users). From that page, click your name, scroll down to the **API Keys** section, and click **Create an IBM Cloud API key**. Give your key a name and click **Create**, then copy the created key and paste it below. You can also get a service specific url by going to the [**Endpoint URLs** section of the Watson Machine Learning docs](https://cloud.ibm.com/apidocs/machine-learning).  You can check your instance location in your  <a href="https://console.ng.bluemix.net/catalog/services/ibm-watson-machine-learning/" target="_blank" rel="noopener no referrer">Watson Machine Learning (WML) Service</a> instance details.
#
# You can also get service specific apikey by going to the [**Service IDs** section of the Cloud Console](https://cloud.ibm.com/iam/serviceids).  From that page, click **Create**, then copy the created key and paste it below.
#
# **Action**: Enter your `api_key` and `location` in the following cell.

# %%
# Setup API KEY and runtime url
apikey = 'PASTE YOUR IBM CLOUD API KEY'
location = 'us-south'

# %% [markdown]
# ### Provide inference inputs

# %%
# Inputs for inference

space_name = 'Gen AI Model Deployments for Production'  # PASTE YOUR SPACE NAME
deployment_name = 'Car rental review satisfaction analysis production deployment'  # PASTE YOUR DEPLOYMENT NAME
positive_prompt_input = 'Agent was very friendly and was ready to work with us in upgrading the car rental'  # PASTE YOUR POSITIVE PROMPT INPUT
negative_prompt_input = 'Agent was very nasty and rude'  # PASTE YOUR NEGATIVE PROMPT INPUT

# Choose once negative and once positive prompt to test the notebook
prompt_input = negative_prompt_input

# %% [markdown]
# ### Connect to Watson Machine Learning

# %%
# Connect to watson machine learning service 
wml_credentials = {
    "apikey": apikey,
    "url": 'https://' + location + '.ml.cloud.ibm.com'
}
wml_client = APIClient(wml_credentials)
# Out:
# 04:05:04 INFO:Client successfully initialized

# %% [markdown]
# ## Helper method

# %%
# Helper method to find prompt template details based on the deployment name and space name
def find_prompt_template_details(space_name:str, deployment_name:str):
    spaces = wml_client.spaces.get_details()
    space_id = None
    for space in spaces['resources']:
        if space['entity']['name'] == space_name:
            logger.debug(f"Found space {space}")
            space_id = wml_client.spaces.get_uid(space)
    
    deployment_id = None
    prompt_template_asset_id = None
    inference_url = None
    if space_id is not None:
        wml_client.set.default_space(space_id)
        deployments = wml_client.deployments.get_details()
        for deployment in deployments['resources']:
            if deployment['entity']['name'] == deployment_name:
                logger.debug(f"Found deployment {deployment}")
                deployment_id = wml_client.deployments.get_uid(deployment)
                prompt_template_asset_id = deployment['entity']['prompt_template']['id']
                inference_url = deployment['entity']['status']['inference'][0]['url']

    if prompt_template_asset_id is not None:
        prompt_template_details = wml_client.data_assets.get_details(asset_uid=prompt_template_asset_id)
        prompt_variable_names = prompt_template_details['entity']['wx_prompt']['prompt_variables'].keys()

    return space_id, deployment_id, inference_url, prompt_variable_names

# %% [markdown]
# ## Find prompt template deployment details

# %% [markdown]
# ### Find prompt template deployment details from deployment space

# %%
# Find prompt template details
space_id, deployment_id, inference_url, prompt_variable_names = find_prompt_template_details(space_name, deployment_name)
logger.info (f"Prompt template space id : {space_id} deployment id : {deployment_id}, inference_url id : {inference_url}, prompt_variable_names : {prompt_variable_names} ")
# Out:
# 04:05:04 INFO:Successfully finished spaces for url: 'https://api.dataplatform.cloud.ibm.com/v2/spaces?version=2023-12-05&limit=200'
# 04:05:04 DEBUG:Response(GET https://api.dataplatform.cloud.ibm.com/v2/spaces?version=2023-12-05&limit=200): {
#   "first": {
#     "href": "https://api.dataplatform.cloud.ibm.com/v2/spaces?version=2023-12-05&limit=200"
#   },
#   "limit": 200,
#   "resources": [{
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/b11ef9462fd5cd198951947913b3ccff:e0ec79ab-c7e2-4a9a-8867-631a5acd6e4c::",
#         "guid": "e0ec79ab-c7e2-4a9a-8867-631a5acd6e4c",
#         "name": "Machine Learning-Synergy",
#         "type": "machine_learning"
#       }],
#       "description": "Development deployment space",
#       "name": "AI-Gov-Demo-Development",
#       "scope": {
#         "bss_account_id": "b11ef9462fd5cd198951947913b3ccff"
#       },
#       "stage": {
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "447e9fe7-2493-4dd9-9714-14e58d92f1e5",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "3c6f89f13efb4b4fbad97dcbe4ad83c7",
#               "api_key": "XlzQwRHgOiGLYaDcd7858rpgDRuvtl-igHBZBcEFtgNc",
#               "secret_access_key": "bbbc05daa7b74c1118eaca9b376f6294a4558b5619e1da89",
#               "service_id": "ServiceId-96b18328-ca8b-4956-94ff-34ed822d85a1"
#             },
#             "editor": {
#               "access_key_id": "ece1b2607aaf4199a4556ffd5174c652",
#               "api_key": "oRVd-oqIQzn2cD2GGNw5N18QGLxba8SN7o5DR0583GLk",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:cd65e597-7d29-4fef-b29a-2cc6b2ddd5e5::",
#               "secret_access_key": "007f2b4303204eb5d45a3f0e659ca103c268bdb3be5a751d",
#               "service_id": "ServiceId-9d84b2a8-7f24-4d91-bba3-38f2146c63b4"
#             },
#             "viewer": {
#               "access_key_id": "cd449d97ff6a4c568f23df01b1610504",
#               "api_key": "48PcIwNQhklJSGv78L8HqZa9WYYTSAzb2kWQkm88GWVG",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:cd65e597-7d29-4fef-b29a-2cc6b2ddd5e5::",
#               "secret_access_key": "97fe7a7776ea97f2574d9ad26665bfb6b305579307692e26",
#               "service_id": "ServiceId-a570b6a5-b836-4d6c-9b1a-bb8d02329eb0"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "cd65e597-7d29-4fef-b29a-2cc6b2ddd5e5",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:cd65e597-7d29-4fef-b29a-2cc6b2ddd5e5::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "tags": ["AIGovernance:Development"],
#       "type": "cpd"
#     },
#     "metadata": {
#       "created_at": "2023-04-25T03:08:17.908Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "b3ad315c-8a46-4103-9597-e2483a578854",
#       "updated_at": "2023-04-25T03:08:52.083Z",
#       "url": "/v2/spaces/b3ad315c-8a46-4103-9597-e2483a578854"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/b11ef9462fd5cd198951947913b3ccff:8f0a5ba9-9834-4f7d-aeb3-d5da392845e3::",
#         "guid": "8f0a5ba9-9834-4f7d-aeb3-d5da392845e3",
#         "name": "Machine Learning-dn",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "gen-ai-space",
#       "scope": {
#         "bss_account_id": "b11ef9462fd5cd198951947913b3ccff"
#       },
#       "stage": {
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "c5f0e9e6-b5c7-45aa-a5d8-c9c93c64a009",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "6c07789c36984948881398d3a350c54c",
#               "api_key": "7n_MoDUdwx_ltmvBhwWFOk14_1WSqmRH8AC8IJaEcUk5",
#               "secret_access_key": "778c68cb5fe66bbaa428dc1808adffe09a423e813ef59f0f",
#               "service_id": "ServiceId-4d6af2fc-fcf3-40bd-8c3c-e2e30bbd2c31"
#             },
#             "editor": {
#               "access_key_id": "e86ef441b943419b910fd69e185dfd76",
#               "api_key": "UUAIPLnNy-z4S5i-8bBL7ez9VX1WfuRscf2UAX6Wqda0",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:22eda4ac-c298-4ccf-b752-bb53111fbac2::",
#               "secret_access_key": "692570f14f8403261bbc97e8059eef9c1b3e56149575a138",
#               "service_id": "ServiceId-0f48c83c-1c13-4c51-b45f-cb5828a4e637"
#             },
#             "viewer": {
#               "access_key_id": "7a7d16e7ad6f4a20a2b3a5e0e945bea4",
#               "api_key": "UIfTpugm4EUVTNYwNnfe-Z4iCBOU9Cj0SI9TtTgmqgXj",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:22eda4ac-c298-4ccf-b752-bb53111fbac2::",
#               "secret_access_key": "c7b3455b1fc4334bda6303bab495ada67cb013c6d3a889ed",
#               "service_id": "ServiceId-b47e7cae-3274-43fa-ab3f-8387eaea962e"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "22eda4ac-c298-4ccf-b752-bb53111fbac2",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:22eda4ac-c298-4ccf-b752-bb53111fbac2::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-07-09T05:18:24.397Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "d18200b0-6444-480b-a46d-4cb429d9b41f",
#       "updated_at": "2023-07-12T05:10:12.343Z",
#       "url": "/v2/spaces/d18200b0-6444-480b-a46d-4cb429d9b41f"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/b11ef9462fd5cd198951947913b3ccff:532914d6-1f42-4284-8780-5f544eaae1b9::",
#         "guid": "532914d6-1f42-4284-8780-5f544eaae1b9",
#         "name": "Watson Machine Learning-for_watsonx.ai",
#         "type": "machine_learning"
#       }],
#       "name": "openscale-express-path-5221a8f4-469e-48a2-a1ad-2e402d58474a",
#       "scope": {
#         "bss_account_id": "b11ef9462fd5cd198951947913b3ccff"
#       },
#       "stage": {
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "10f20828-93b1-4f77-ba9f-27cc973843ef",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "14f2a44e778f4d44ae219cba186aeae2",
#               "api_key": "FY8VydR1y4O3VGDovX50xg03S4lXPO-NQWf7QtPWyVCo",
#               "secret_access_key": "77a0eb48a1268483e7edd7624fbe3de9b1b1e94804824bd8",
#               "service_id": "ServiceId-c9250ec8-6d79-49b3-acad-d0adb6f896d5"
#             },
#             "editor": {
#               "access_key_id": "3607265ed6d04ee7b309280f12969d5f",
#               "api_key": "Hza_CN80ds0-UYDLqFtqSa0ECMzBqhnJZ3TebXxj4JuM",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:04fd25e3-4e2f-48a7-bca3-5ddbd16ab876::",
#               "secret_access_key": "26e754e6c8235000c3c0412008a12f814409ad17811c4ff8",
#               "service_id": "ServiceId-e7916e5d-04ee-43e4-b3d3-98863c45a6bf"
#             },
#             "viewer": {
#               "access_key_id": "858fc2e0601c408c89ec6dd410c9f5df",
#               "api_key": "66tTbVW2DELLe_jW2jj1WVo9DYAdnQlXg3j1uNalDq9z",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:04fd25e3-4e2f-48a7-bca3-5ddbd16ab876::",
#               "secret_access_key": "5216d830364d8c1ee7c5292c64711626d597ecf7acd5083c",
#               "service_id": "ServiceId-eaaa8564-3c7d-47ca-be62-3d9168a6c59a"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "04fd25e3-4e2f-48a7-bca3-5ddbd16ab876",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:04fd25e3-4e2f-48a7-bca3-5ddbd16ab876::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "type": "cpd"
#     },
#     "metadata": {
#       "created_at": "2023-11-09T11:53:45.125Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "fd4cb026-6d19-40d8-9897-421e367df95f",
#       "updated_at": "2023-11-09T11:54:05.743Z",
#       "url": "/v2/spaces/fd4cb026-6d19-40d8-9897-421e367df95f"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/b11ef9462fd5cd198951947913b3ccff:532914d6-1f42-4284-8780-5f544eaae1b9::",
#         "guid": "532914d6-1f42-4284-8780-5f544eaae1b9",
#         "name": "Watson Machine Learning-for_watsonx.ai",
#         "type": "machine_learning"
#       }],
#       "name": "openscale-express-path-preprod-5221a8f4-469e-48a2-a1ad-2e402d58474a",
#       "scope": {
#         "bss_account_id": "b11ef9462fd5cd198951947913b3ccff"
#       },
#       "stage": {
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "6c99f29f-df2a-4464-baf1-149e8f39834e",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "ca80fb73047240b09bdec8445eedf559",
#               "api_key": "Jw-rRLO8sM4vP6I0IQvQHUsh6mjl95VDS_8APDLr3a9x",
#               "secret_access_key": "17b9988bcde909cf7912c3480c33b9bbb020df12601f8772",
#               "service_id": "ServiceId-b07b8274-5c87-4106-a1e4-817a7cc1623d"
#             },
#             "editor": {
#               "access_key_id": "6237811b0dd64380b5c06f9bc17efe4b",
#               "api_key": "sJXLX72sdbNZ0K1XHqw7mIU7wfOcAEtjZVm4PLOVnvV7",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:04fd25e3-4e2f-48a7-bca3-5ddbd16ab876::",
#               "secret_access_key": "ec5aade94bd5a928553ab8b6e9818ab26ffb740e04e78c59",
#               "service_id": "ServiceId-13856c17-5f7f-43e2-83eb-94ebf6944820"
#             },
#             "viewer": {
#               "access_key_id": "0d004af8c7b748b7b0badd016cea168b",
#               "api_key": "1QaQqfi8wQ72hZzHzhVsMaM4WI--xmMEszitHDLs0sKK",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:04fd25e3-4e2f-48a7-bca3-5ddbd16ab876::",
#               "secret_access_key": "fd9af95597f8e546d7e9cde57dd3765e186626ec4b4f8d6f",
#               "service_id": "ServiceId-07e9bf5c-15e1-422e-9dd3-8f22d347f8c1"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "04fd25e3-4e2f-48a7-bca3-5ddbd16ab876",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/b11ef9462fd5cd198951947913b3ccff:04fd25e3-4e2f-48a7-bca3-5ddbd16ab876::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "type": "cpd"
#     },
#     "metadata": {
#       "created_at": "2023-11-09T11:54:06.685Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "bdad9bae-74ce-444a-b728-fa8a46cfaf5d",
#       "updated_at": "2023-11-09T11:54:24.406Z",
#       "url": "/v2/spaces/bdad9bae-74ce-444a-b728-fa8a46cfaf5d"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:09445407-e2ec-431b-a2c7-974f0a040f4c::",
#         "guid": "09445407-e2ec-431b-a2c7-974f0a040f4c",
#         "name": "Watson Machine Learning-tel-se-watsonx",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "Foundation Model Deployment - Testing and Validation",
#       "scope": {
#         "bss_account_id": "3bde3b8a1d624d6fb4e5bd1283cbfd14"
#       },
#       "stage": {
#         "name": "Testing",
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "b9405c3c-1bf7-4b8d-941a-d87b81681ee3",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "bcdc694daca8491ea83db76335fe6cbc",
#               "api_key": "vzXf_OQ9jO1u3VqOKxMLzhrDo6yVQ-7xJuUpMSoRn9Bh",
#               "secret_access_key": "1bb9fcf67f925b9e0dbfdafbe5f4c9d70064158a2de41cea",
#               "service_id": "ServiceId-1915bc05-d871-408a-9f4a-392c765d56f7"
#             },
#             "editor": {
#               "access_key_id": "d2edebb0d4c748e9b71f7092e5976aba",
#               "api_key": "7Wv4_99EKi1KcTKOPUe0JcPM7tIeYCVEmArWKRtPjQ3-",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "d13629070bbdd211465a0922938e60ced39f928186be5d40",
#               "service_id": "ServiceId-fd018b59-7a28-4ead-a75b-bec5dfc3165f"
#             },
#             "viewer": {
#               "access_key_id": "e4e51d497b4b4d96bd6fb4c28f76b3bf",
#               "api_key": "enDqqYvMAY5R0ujBS6gwPYgxwXqETI6BzdyQoaQDch40",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "5991e6846682c67745a563c95bf2980b4a0609f547196467",
#               "service_id": "ServiceId-6bcb13ba-44f4-416c-a0eb-061cf8aee7fa"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "6c53e402-aef0-4f44-9e8f-acd46142b8eb",
#           "plan_id": "744bfc56-d12c-4866-88d5-dac9139e0e5d",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "tags": ["AIGovernance:Preproduction"],
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-12-01T18:31:39.796Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "54f757f2-8614-41c4-b875-a8db00ffdff8",
#       "updated_at": "2023-12-01T18:32:01.179Z",
#       "url": "/v2/spaces/54f757f2-8614-41c4-b875-a8db00ffdff8"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:09445407-e2ec-431b-a2c7-974f0a040f4c::",
#         "guid": "09445407-e2ec-431b-a2c7-974f0a040f4c",
#         "name": "Watson Machine Learning-tel-se-watsonx",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "Gen AI Model Deployments for Validation",
#       "scope": {
#         "bss_account_id": "3bde3b8a1d624d6fb4e5bd1283cbfd14"
#       },
#       "stage": {
#         "name": "Testing",
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "b5057f19-213e-49e1-bc76-60b79640708b",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "8c6ad0dde5e746b0b2bbe35efa2310f4",
#               "api_key": "q-kXdud_5I8xqRwLmCUql-j8fyI1yDqfRRoOn3LkYY9s",
#               "secret_access_key": "9044c97354034c68df9e7ab73c8e87d027818de8c1ce7e77",
#               "service_id": "ServiceId-7daba803-bcc9-4089-a36c-04fb10d320ef"
#             },
#             "editor": {
#               "access_key_id": "8ccb60dd7fe84ec1b2040c7d3eb544dc",
#               "api_key": "zxuA0vk0AeU_KIGxJ6PSB-kv8_QE_saxEZLzIDECYCVg",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "16fbf30725e01eae6a69b753be351b0d1ef00a23be64a99d",
#               "service_id": "ServiceId-fafba03b-e8ab-430d-9754-68dce241d68c"
#             },
#             "viewer": {
#               "access_key_id": "fb200b84ae8c422db4b45452ce8dd79b",
#               "api_key": "sU1vzsXMtREsfA3bG9bUHiJ7sQI0UJVUj15cP6meywtk",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "c1a875fade9d2e9d71a07aaa5ef5b3100cb11bc141a584e1",
#               "service_id": "ServiceId-fd81688d-6320-4228-b4b1-bc5d86c61806"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "6c53e402-aef0-4f44-9e8f-acd46142b8eb",
#           "plan_id": "744bfc56-d12c-4866-88d5-dac9139e0e5d",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "tags": [],
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-12-05T17:43:42.633Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "8a4a457f-aa96-4dbc-a1dd-15bae050c340",
#       "updated_at": "2023-12-13T13:23:32.880Z",
#       "url": "/v2/spaces/8a4a457f-aa96-4dbc-a1dd-15bae050c340"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:09445407-e2ec-431b-a2c7-974f0a040f4c::",
#         "guid": "09445407-e2ec-431b-a2c7-974f0a040f4c",
#         "name": "Watson Machine Learning-tel-se-watsonx",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "Gen AI Model Deployments for Productions",
#       "scope": {
#         "bss_account_id": "3bde3b8a1d624d6fb4e5bd1283cbfd14"
#       },
#       "stage": {
#         "name": "Production",
#         "production": true
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "3883afb7-5529-419a-8a30-87a5f8a4b348",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "1a53bcd793654930a599c6de3bdb76de",
#               "api_key": "Y5lAV39lSsXfbXIFbNkw8kojXofT2EBog66TQMG0eyOb",
#               "secret_access_key": "81c66e2ec3c05723874ea29b7c54ee6e1565aa9d354c6d25",
#               "service_id": "ServiceId-862e99b5-aaa2-4bd6-b169-bfe5911de486"
#             },
#             "editor": {
#               "access_key_id": "ea64c756a2834cba8063fcc52b03a36c",
#               "api_key": "KJEUt-6GhNHPjAxKaRM58Vf6UQEXJ2BhZrDciDmqTYrf",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "071511cc4b90b639406828ef6d913795b5007147a8f838c9",
#               "service_id": "ServiceId-fb099016-3126-4751-b5c6-f5f069af5360"
#             },
#             "viewer": {
#               "access_key_id": "42987e59d4ba4048ade97e0d2cb535fa",
#               "api_key": "4ifDZJlrq_yPTz2h2v1wAIZZa6u4Vdn_HYzkBdtbxKRT",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "b9b4efa960fc2367419153ffbc4cf94dc588e3607d920923",
#               "service_id": "ServiceId-f13dc205-b39d-4861-bd31-9187bce0b2c0"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "6c53e402-aef0-4f44-9e8f-acd46142b8eb",
#           "plan_id": "744bfc56-d12c-4866-88d5-dac9139e0e5d",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "tags": [],
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-12-08T02:49:38.736Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "0fd619ef-06a9-4a7a-a3d6-8feb065aa729",
#       "updated_at": "2023-12-13T14:16:15.113Z",
#       "url": "/v2/spaces/0fd619ef-06a9-4a7a-a3d6-8feb065aa729"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/7967abc0d9884cefa22587682b80f319:007b3de2-89e4-4706-8f3f-44540f74eeb2::",
#         "guid": "007b3de2-89e4-4706-8f3f-44540f74eeb2",
#         "name": "Watson Machine Learning-watsonx-gov-bootcamp-students",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "deployment-space-watsonx-gov-bootcamp-students-development",
#       "scope": {
#         "bss_account_id": "7967abc0d9884cefa22587682b80f319"
#       },
#       "stage": {
#         "name": "Development",
#         "production": false
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "baa2eadc-af24-4106-bfcb-a0c5fbf4d07f",
#           "bucket_region": "us-south",
#           "credentials": {
#             "editor": {
#               "access_key_id": "2a1d33f8db3340118ffe782ad0a0ef02",
#               "api_key": "FJBPYzheJPJ6FQyQRGzqWfkBgAavt6SwLOq49jQdY1qw",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/7967abc0d9884cefa22587682b80f319:e417e958-86c7-44dc-9d4d-4d3d048cb33e::",
#               "secret_access_key": "465273805f7e379aff4d7e7a167e4a9c030c92b6b76b0585",
#               "service_id": "ServiceId-13dadac3-a1f2-448e-85a6-5cfc3403c278"
#             },
#             "viewer": {
#               "access_key_id": "8c49de36f3314ac39d995605c91c6d15",
#               "api_key": "TQ-69f3BCTp0OLltxRNa6qHbxLRCAv5ZHFy_IgotdnIZ",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/7967abc0d9884cefa22587682b80f319:e417e958-86c7-44dc-9d4d-4d3d048cb33e::",
#               "secret_access_key": "3b019a3553aed3fda6513803b5f136b03a5429c73aa75a07",
#               "service_id": "ServiceId-e0081627-807c-46bd-8b33-372df8ecca79"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "e417e958-86c7-44dc-9d4d-4d3d048cb33e",
#           "plan_id": "744bfc56-d12c-4866-88d5-dac9139e0e5d",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/7967abc0d9884cefa22587682b80f319:e417e958-86c7-44dc-9d4d-4d3d048cb33e::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-12-08T19:38:24.238Z",
#       "creator_id": "IBMid-550008WHPN",
#       "id": "1e2f4efc-f376-46ac-98de-c50065e6b693",
#       "updated_at": "2023-12-08T21:17:11.263Z",
#       "url": "/v2/spaces/1e2f4efc-f376-46ac-98de-c50065e6b693"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/7967abc0d9884cefa22587682b80f319:007b3de2-89e4-4706-8f3f-44540f74eeb2::",
#         "guid": "007b3de2-89e4-4706-8f3f-44540f74eeb2",
#         "name": "Watson Machine Learning-watsonx-gov-bootcamp-students",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "deployment-space-watsonx-gov-bootcamp-students-production",
#       "scope": {
#         "bss_account_id": "7967abc0d9884cefa22587682b80f319"
#       },
#       "stage": {
#         "name": "Production",
#         "production": true
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "86829d2d-d47b-433b-a9e5-907e12e4701c",
#           "bucket_region": "us-south",
#           "credentials": {
#             "editor": {
#               "access_key_id": "f43d4b8d4d1a4973b027eed93ad7a4d2",
#               "api_key": "WlvF6Ab7_nlyzNpzGCqhYT6iIWoxFmk44dHCypoAAz77",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/7967abc0d9884cefa22587682b80f319:e417e958-86c7-44dc-9d4d-4d3d048cb33e::",
#               "secret_access_key": "81445e5e930b3b16739ec4bd9c201fe4170ab1b80316a604",
#               "service_id": "ServiceId-c4f43878-7fb0-45da-93ff-7a92f0f91ddf"
#             },
#             "viewer": {
#               "access_key_id": "9e52c19d086b4cae8910860843d2239e",
#               "api_key": "nxYo3L2nGGAGYEwyKcagHwyNFPq6By5IQfVU0fL-JlPc",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/7967abc0d9884cefa22587682b80f319:e417e958-86c7-44dc-9d4d-4d3d048cb33e::",
#               "secret_access_key": "24175ae9b5cef85b5277612b8ec9a1d5f5ff8e6a06e1d7f6",
#               "service_id": "ServiceId-4ffba51e-2669-4e6a-9b49-10039dec30e7"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "e417e958-86c7-44dc-9d4d-4d3d048cb33e",
#           "plan_id": "744bfc56-d12c-4866-88d5-dac9139e0e5d",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/7967abc0d9884cefa22587682b80f319:e417e958-86c7-44dc-9d4d-4d3d048cb33e::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-12-08T21:18:44.514Z",
#       "creator_id": "IBMid-550008WHPN",
#       "id": "b543d813-0484-4dc9-a4b1-1f0991e35e45",
#       "updated_at": "2023-12-08T21:19:03.564Z",
#       "url": "/v2/spaces/b543d813-0484-4dc9-a4b1-1f0991e35e45"
#     }
#   }, {
#     "entity": {
#       "compute": [{
#         "crn": "crn:v1:bluemix:public:pm-20:us-south:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:09445407-e2ec-431b-a2c7-974f0a040f4c::",
#         "guid": "09445407-e2ec-431b-a2c7-974f0a040f4c",
#         "name": "Watson Machine Learning-tel-se-watsonx",
#         "type": "machine_learning"
#       }],
#       "description": "",
#       "name": "Gen AI Model Deployments for Production",
#       "scope": {
#         "bss_account_id": "3bde3b8a1d624d6fb4e5bd1283cbfd14"
#       },
#       "stage": {
#         "name": "Production",
#         "production": true
#       },
#       "status": {
#         "state": "active"
#       },
#       "storage": {
#         "properties": {
#           "bucket_name": "a99653a0-4f41-4a17-b172-efea9cf7eaed",
#           "bucket_region": "us-south",
#           "credentials": {
#             "admin": {
#               "access_key_id": "c88b717eb619401bab43d3497ccf8fcc",
#               "api_key": "YIofM0L3a84zHUQF0GaNdnzDj2lQvEEw42SOZoZo6unY",
#               "secret_access_key": "c7984f63a18933a85091142049d6c014ad7ab4b45a153ec2",
#               "service_id": "ServiceId-35a05dcb-dfff-4864-9b9d-bcacc24b35c0"
#             },
#             "editor": {
#               "access_key_id": "5cabce9843c14ae79fc9f429a7ee59b4",
#               "api_key": "uH56dG90XQBYz5B09b_ShO2-Lxy791D4kae5kUFfPS-2",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "cb0f754d0418a53b2683ec508a060b5383f75b893d836f31",
#               "service_id": "ServiceId-ecf77bfd-c8ef-463e-b395-337452bb518c"
#             },
#             "viewer": {
#               "access_key_id": "5cd2e03cf3824fb4b4607020543b9972",
#               "api_key": "hSRrnwZ-CkThSvO-PyiqHerwdAlbJpiBCLU1TQkWvOQU",
#               "resource_key_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::",
#               "secret_access_key": "0294776e15d4f53d37cf23c014a51835d52a9002f2c33c74",
#               "service_id": "ServiceId-8cbdc403-be9a-43af-9668-e6ffa1cb6958"
#             }
#           },
#           "endpoint_url": "https://s3.us-south.cloud-object-storage.appdomain.cloud",
#           "guid": "6c53e402-aef0-4f44-9e8f-acd46142b8eb",
#           "plan_id": "744bfc56-d12c-4866-88d5-dac9139e0e5d",
#           "resource_crn": "crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::"
#         },
#         "type": "bmcos_object_storage"
#       },
#       "type": "wx"
#     },
#     "metadata": {
#       "created_at": "2023-12-14T19:42:21.227Z",
#       "creator_id": "IBMid-0600019M7F",
#       "id": "566d4549-253a-489c-8173-d3a9c92bb027",
#       "updated_at": "2023-12-14T19:42:33.921Z",
#       "url": "/v2/spaces/566d4549-253a-489c-8173-d3a9c92bb027"
#     }
#   }]
# }
# 04:05:04 DEBUG:Found space {'entity': {'compute': [{'crn': 'crn:v1:bluemix:public:pm-20:us-south:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:09445407-e2ec-431b-a2c7-974f0a040f4c::', 'guid': '09445407-e2ec-431b-a2c7-974f0a040f4c', 'name': 'Watson Machine Learning-tel-se-watsonx', 'type': 'machine_learning'}], 'description': '', 'name': 'Gen AI Model Deployments for Production', 'scope': {'bss_account_id': '3bde3b8a1d624d6fb4e5bd1283cbfd14'}, 'stage': {'name': 'Production', 'production': True}, 'status': {'state': 'active'}, 'storage': {'properties': {'bucket_name': 'a99653a0-4f41-4a17-b172-efea9cf7eaed', 'bucket_region': 'us-south', 'credentials': {'admin': {'access_key_id': 'c88b717eb619401bab43d3497ccf8fcc', 'api_key': 'YIofM0L3a84zHUQF0GaNdnzDj2lQvEEw42SOZoZo6unY', 'secret_access_key': 'c7984f63a18933a85091142049d6c014ad7ab4b45a153ec2', 'service_id': 'ServiceId-35a05dcb-dfff-4864-9b9d-bcacc24b35c0'}, 'editor': {'access_key_id': '5cabce9843c14ae79fc9f429a7ee59b4', 'api_key': 'uH56dG90XQBYz5B09b_ShO2-Lxy791D4kae5kUFfPS-2', 'resource_key_crn': 'crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::', 'secret_access_key': 'cb0f754d0418a53b2683ec508a060b5383f75b893d836f31', 'service_id': 'ServiceId-ecf77bfd-c8ef-463e-b395-337452bb518c'}, 'viewer': {'access_key_id': '5cd2e03cf3824fb4b4607020543b9972', 'api_key': 'hSRrnwZ-CkThSvO-PyiqHerwdAlbJpiBCLU1TQkWvOQU', 'resource_key_crn': 'crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::', 'secret_access_key': '0294776e15d4f53d37cf23c014a51835d52a9002f2c33c74', 'service_id': 'ServiceId-8cbdc403-be9a-43af-9668-e6ffa1cb6958'}}, 'endpoint_url': 'https://s3.us-south.cloud-object-storage.appdomain.cloud', 'guid': '6c53e402-aef0-4f44-9e8f-acd46142b8eb', 'plan_id': '744bfc56-d12c-4866-88d5-dac9139e0e5d', 'resource_crn': 'crn:v1:bluemix:public:cloud-object-storage:global:a/3bde3b8a1d624d6fb4e5bd1283cbfd14:6c53e402-aef0-4f44-9e8f-acd46142b8eb::'}, 'type': 'bmcos_object_storage'}, 'type': 'wx'}, 'metadata': {'created_at': '2023-12-14T19:42:21.227Z', 'creator_id': 'IBMid-0600019M7F', 'id': '566d4549-253a-489c-8173-d3a9c92bb027', 'updated_at': '2023-12-14T19:42:33.921Z', 'url': '/v2/spaces/566d4549-253a-489c-8173-d3a9c92bb027'}}
# 04:05:05 INFO:Successfully finished deployments for url: 'https://us-south.ml.cloud.ibm.com/ml/v4/deployments?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027&limit=200'
# 04:05:05 DEBUG:Response(GET https://us-south.ml.cloud.ibm.com/ml/v4/deployments?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027&limit=200): {
#   "resources": [{
#     "entity": {
#       "base_model_id": "ibm/granite-13b-instruct-v2",
#       "custom": {
#
#       },
#       "deployed_asset_type": "prompt_template",
#       "name": "Car rental review satisfaction analysis production deployment",
#       "online": {
#
#       },
#       "prompt_template": {
#         "id": "ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4"
#       },
#       "space_id": "566d4549-253a-489c-8173-d3a9c92bb027",
#       "status": {
#         "inference": [{
#           "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text"
#         }, {
#           "sse": true,
#           "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"
#         }],
#         "serving_urls": ["https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text", "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"],
#         "state": "ready"
#       }
#     },
#     "metadata": {
#       "created_at": "2023-12-14T19:48:25.897Z",
#       "id": "22905dc9-3d72-427a-91d2-8e3ddbae8b3b",
#       "modified_at": "2023-12-17T03:55:06.387Z",
#       "name": "Car rental review satisfaction analysis production deployment",
#       "owner": "IBMid-0600019M7F",
#       "space_id": "566d4549-253a-489c-8173-d3a9c92bb027"
#     },
#     "system": {
#       "warnings": [{
#         "id": "Deprecated",
#         "message": "online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead."
#       }]
#     }
#   }]
# }
# 04:05:05 DEBUG:Found deployment {'entity': {'base_model_id': 'ibm/granite-13b-instruct-v2', 'custom': {}, 'deployed_asset_type': 'prompt_template', 'name': 'Car rental review satisfaction analysis production deployment', 'online': {}, 'prompt_template': {'id': 'ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4'}, 'space_id': '566d4549-253a-489c-8173-d3a9c92bb027', 'status': {'inference': [{'url': 'https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text'}, {'sse': True, 'url': 'https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream'}], 'serving_urls': ['https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text', 'https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream'], 'state': 'ready'}}, 'metadata': {'created_at': '2023-12-14T19:48:25.897Z', 'id': '22905dc9-3d72-427a-91d2-8e3ddbae8b3b', 'modified_at': '2023-12-17T03:55:06.387Z', 'name': 'Car rental review satisfaction analysis production deployment', 'owner': 'IBMid-0600019M7F', 'space_id': '566d4549-253a-489c-8173-d3a9c92bb027'}, 'system': {'warnings': [{'id': 'Deprecated', 'message': 'online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead.'}]}}
# 04:05:05 INFO:Successfully finished get data_asset details for url: 'https://api.dataplatform.cloud.ibm.com/v2/assets/ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027'
# 04:05:05 DEBUG:Response(GET https://api.dataplatform.cloud.ibm.com/v2/assets/ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027): {"metadata":{"space_id":"566d4549-253a-489c-8173-d3a9c92bb027","usage":{"last_updated_at":"2023-12-17T03:55:05Z","last_updater_id":"iam-ServiceId-4e678d10-eb31-4193-9ec3-86c0313ab18d","last_update_time":1702785305891,"last_accessed_at":"2023-12-17T03:55:05Z","last_access_time":1702785305891,"last_accessor_id":"iam-ServiceId-4e678d10-eb31-4193-9ec3-86c0313ab18d","access_count":0},"rov":{"mode":0,"collaborator_ids":{},"member_roles":{"IBMid-0600019M7F":{"user_iam_id":"IBMid-0600019M7F","roles":["OWNER"]}}},"name":"Car rental review satisfaction analysis","description":"","asset_type":"wx_prompt","origin_country":"us","resource_key":"b0d4dc3294a6621e6a57c31313fd8457d516229e590d12c60a771c122501e564","rating":0.0,"total_ratings":0,"catalog_id":"bcba40b0-920b-49c5-891e-bae37d5972b0","created":1702583046657,"created_at":"2023-12-14T19:44:06Z","owner_id":"IBMid-0600019M7F","size":807,"version":2.0,"asset_state":"available","asset_attributes":["wx_prompt","modelfacts_system","modelfacts_user"],"asset_id":"ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4","source_asset":{"action":"promote","catalog_id":"f39b5420-d81a-4cde-bf08-b1ed04f2561b","project_id":"26329aec-3a9c-4399-ad0a-8316c6729832","asset_id":"1163880c-5128-46f3-9064-1f0d990d73a4","bss_account_id":"3bde3b8a1d624d6fb4e5bd1283cbfd14","asset_name":"Car rental review satisfaction analysis","resource_key":"b0d4dc3294a6621e6a57c31313fd8457d516229e590d12c60a771c122501e564"},"asset_category":"USER","creator_id":"IBMid-0600019M7F"},"entity":{"wx_prompt":{"task_ids":["classification"],"is_template":true,"prompt_variables":{"Review":{"default_value":"Agent was nasty"}},"model_version":{"number":"0.0.3","tag":"50b02e75-ac80-4d3c-9616-c2cc3a6d3a07","description":""},"locked_by":"IBMid-0600019M7F","lock_type":"governance"},"location_definition":{"physical_location_code":"DAL","physical_location_code_assigned_by":"IBMid-0600019M7F","physical_location_code_rds_id":"c57cb90f-2126-3800-9c9f-9eab82021cdf","physical_location_code_rds_version":"00002022-0616-4174-8514-839516000000_2","physical_location_code_assignment_method":"INFERRED","physical_location_code_added_on":"1702368555988"},"modelfacts_system":{"model_information":{"model_type":"","model_description":"","input_type":"unstructured_text","algorithm":"","prediction_type":"classification","software_spec":"","software_spec_id":"","asset_type":"wx_prompt","label_column":""},"training_information":{"project_name":"Model Lifecycle Management with Watsonx Demo","training_data_references":[],"hyper_parameters":"","hybrid_pipeline":[],"features":0},"model_identity_information":{"master_id":"b0d4dc3294a6621e6a57c31313fd8457d516229e590d12c60a771c122501e564","model_identity_key":"b0d4dc3294a6621e6a57c31313fd8457d516229e590d12c60a771c122501e564"},"modelentry_information":{"lmid":"d454a4ec-7904-4ea4-8b75-f4e5935434d6:64e18d76-a0b8-4a18-beb9-a170919b02a2"},"space_details":{"space_id":"566d4549-253a-489c-8173-d3a9c92bb027","space_type":"production","is_spacetype_openscale_value":true},"deployment_details":[{"id":"22905dc9-3d72-427a-91d2-8e3ddbae8b3b","openscale_details":{"href":"https://aiopenscale.cloud.ibm.com/aiopenscale/insights/eaf6cb14-80d9-41c5-a919-0b7573f459af","service_instance_id":"cc5e126e-17ee-493d-bff5-697cb87fd277","subscription_id":"eaf6cb14-80d9-41c5-a919-0b7573f459af","service_provider":{"id":"f91b2725-71ae-4dd6-9082-6477cb95df98","type":"watson_machine_learning","name":"SPACE_566d4549-253a-489c-8173-d3a9c92bb027","environment_type":"production"},"bss_account_id":"3bde3b8a1d624d6fb4e5bd1283cbfd14","data_sources":[{"type":"feedback","storage_type":"db2","is_internal_database":false,"host":"24013820-da9f-4e69-a7d6-17efc5d30a33.c8l9ggsd0kmvoig3l8kg.databases.appdomain.cloud","port":31613,"database_name":"bludb","schema_name":"aiopenscale00","table_name":"Feedback_eaf6cb14 ...
# 04:05:05 INFO:Prompt template space id : 566d4549-253a-489c-8173-d3a9c92bb027 deployment id : 22905dc9-3d72-427a-91d2-8e3ddbae8b3b, inference_url id : https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text, prompt_variable_names : dict_keys(['Review'])

# %% [markdown]
# ## Prepare inference payload

# %%
# Add prompt variables to inference payload
prompt_variables = {}
for variable_name in prompt_variable_names:
    prompt_variables[variable_name] = prompt_input

prompt_params = {}
prompt_params['prompt_variables'] = prompt_variables 
logger.info(f"Prompt params for inference {prompt_params}")
# Out:
# 04:05:05 INFO:Prompt params for inference {'prompt_variables': {'Review': 'Agent was very nasty and rude'}}

# %% [markdown]
# ## Call inference endpoint

# %% [markdown]
# ### Approach 1: Call inference endpoint using WML API client and  prompt template deployment using Python SDK

# %%
# Call inference endpoint using WML Deployments 
generated_text_using_deployment = wml_client.deployments.generate_text(deployment_id, params=prompt_params)
logger.info(f"Generated text using deployment: {generated_text_using_deployment}")
# Out:
# 04:05:05 INFO:Successfully finished getting deployments details for url: 'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027'
# 04:05:05 DEBUG:Response(GET https://us-south.ml.cloud.ibm.com/ml/v4/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027): {
#   "entity": {
#     "base_model_id": "ibm/granite-13b-instruct-v2",
#     "custom": {
#
#     },
#     "deployed_asset_type": "prompt_template",
#     "name": "Car rental review satisfaction analysis production deployment",
#     "online": {
#
#     },
#     "prompt_template": {
#       "id": "ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4"
#     },
#     "space_id": "566d4549-253a-489c-8173-d3a9c92bb027",
#     "status": {
#       "inference": [{
#         "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text"
#       }, {
#         "sse": true,
#         "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"
#       }],
#       "serving_urls": ["https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text", "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"],
#       "state": "ready"
#     }
#   },
#   "metadata": {
#     "created_at": "2023-12-14T19:48:25.897Z",
#     "id": "22905dc9-3d72-427a-91d2-8e3ddbae8b3b",
#     "modified_at": "2023-12-17T03:55:06.387Z",
#     "name": "Car rental review satisfaction analysis production deployment",
#     "owner": "IBMid-0600019M7F",
#     "space_id": "566d4549-253a-489c-8173-d3a9c92bb027"
#   },
#   "system": {
#     "warnings": [{
#       "id": "Deprecated",
#       "message": "online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead."
#     }]
#   }
# }
# 04:05:06 INFO:Successfully finished getting deployments details for url: 'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027'
# 04:05:06 DEBUG:Response(GET https://us-south.ml.cloud.ibm.com/ml/v4/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027): {
#   "entity": {
#     "base_model_id": "ibm/granite-13b-instruct-v2",
#     "custom": {
#
#     },
#     "deployed_asset_type": "prompt_template",
#     "name": "Car rental review satisfaction analysis production deployment",
#     "online": {
#
#     },
#     "prompt_template": {
#       "id": "ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4"
#     },
#     "space_id": "566d4549-253a-489c-8173-d3a9c92bb027",
#     "status": {
#       "inference": [{
#         "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text"
#       }, {
#         "sse": true,
#         "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"
#       }],
#       "serving_urls": ["https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text", "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"],
#       "state": "ready"
#     }
#   },
#   "metadata": {
#     "created_at": "2023-12-14T19:48:25.897Z",
#     "id": "22905dc9-3d72-427a-91d2-8e3ddbae8b3b",
#     "modified_at": "2023-12-17T03:55:06.387Z",
#     "name": "Car rental review satisfaction analysis production deployment",
#     "owner": "IBMid-0600019M7F",
#     "space_id": "566d4549-253a-489c-8173-d3a9c92bb027"
#   },
#   "system": {
#     "warnings": [{
#       "id": "Deprecated",
#       "message": "online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead."
#     }]
#   }
# }
# 04:05:07 INFO:Successfully finished _load_json_prompt for url: 'https://api.dataplatform.cloud.ibm.com/wx/v1-beta/prompts/ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4?space_id=566d4549-253a-489c-8173-d3a9c92bb027&prompt_id=ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4'
# 04:05:07 DEBUG:Response(GET https://api.dataplatform.cloud.ibm.com/wx/v1-beta/prompts/ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4?space_id=566d4549-253a-489c-8173-d3a9c92bb027&prompt_id=ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4): {"id":"ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4","name":"Car rental review satisfaction analysis","description":"","created_at":1702583046657,"created_by":"IBMid-0600019M7F","last_updated_at":1702785305891,"last_updated_by":"iam-ServiceId-4e678d10-eb31-4193-9ec3-86c0313ab18d","resource_key":"b0d4dc3294a6621e6a57c31313fd8457d516229e590d12c60a771c122501e564","lock":{"locked":true,"locked_by":"IBMid-0600019M7F","lock_type":"governance"},"model_version":{"number":"0.0.3","tag":"50b02e75-ac80-4d3c-9616-c2cc3a6d3a07","description":""},"is_template":true,"prompt_variables":{"Review":{"default_value":"Agent was nasty"}},"task_ids":["classification"],"prompt":{"model_id":"ibm/granite-13b-instruct-v2","model_parameters":{"decoding_method":"greedy","max_new_tokens":20,"min_new_tokens":0,"random_seed":null,"stop_sequences":[],"temperature":0.7,"top_k":50,"top_p":1,"repetition_penalty":1},"data":{"instruction":"Determine if the customer was satisfied with the experience based on the comment. Return simple yes or no.","input_prefix":"Review:","output_prefix":"Satisfied","examples":[["I thought the representative handled the initial situation badly.  The company was out of cars, with none coming in that day.  Then the representative tried to find us a car at another franchise.  There they were successful.","no"],["The car rental agent was very helpful. He worked with us to get a bigger car for very little additional fees","yes"]]},"input":[["{Review}",""]]}}
# 04:05:09 INFO:Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text?version=2023-12-05'
# 04:05:09 DEBUG:Response(POST https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text?version=2023-12-05): {"model_id":"ibm/granite-13b-instruct-v2","created_at":"2023-12-17T04:05:08.639Z","results":[{"generated_text":"no\n\n","generated_token_count":3,"input_token_count":117,"stop_reason":"eos_token"}]}
# 04:05:09 INFO:Generated text using deployment: no

# %% [markdown]
# ### Approach 2: Call inference endpoint using Model Inference pointing to prompt template deployment using Python SDK

# %%
# Call inference endpoint using ModelInference
from ibm_watson_machine_learning.foundation_models import ModelInference
model_inference = ModelInference(
    deployment_id=deployment_id,
    credentials={
        'apikey': apikey,
        'url': 'https://' + location + '.ml.cloud.ibm.com'
    },
    space_id=space_id
    )
generated_text_using_model_inference = model_inference.generate_text(params = prompt_params)
logger.info(f"Generated text using model inference: {generated_text_using_model_inference}")
# Out:
# 04:05:11 INFO:Client successfully initialized
# 04:05:11 INFO:Successfully finished getting deployments details for url: 'https://us-south.ml.cloud.ibm.com/ml/v4/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027'
# 04:05:11 DEBUG:Response(GET https://us-south.ml.cloud.ibm.com/ml/v4/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b?version=2023-12-05&space_id=566d4549-253a-489c-8173-d3a9c92bb027): {
#   "entity": {
#     "base_model_id": "ibm/granite-13b-instruct-v2",
#     "custom": {
#
#     },
#     "deployed_asset_type": "prompt_template",
#     "name": "Car rental review satisfaction analysis production deployment",
#     "online": {
#
#     },
#     "prompt_template": {
#       "id": "ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4"
#     },
#     "space_id": "566d4549-253a-489c-8173-d3a9c92bb027",
#     "status": {
#       "inference": [{
#         "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text"
#       }, {
#         "sse": true,
#         "url": "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"
#       }],
#       "serving_urls": ["https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text", "https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text_stream"],
#       "state": "ready"
#     }
#   },
#   "metadata": {
#     "created_at": "2023-12-14T19:48:25.897Z",
#     "id": "22905dc9-3d72-427a-91d2-8e3ddbae8b3b",
#     "modified_at": "2023-12-17T03:55:06.387Z",
#     "name": "Car rental review satisfaction analysis production deployment",
#     "owner": "IBMid-0600019M7F",
#     "space_id": "566d4549-253a-489c-8173-d3a9c92bb027"
#   },
#   "system": {
#     "warnings": [{
#       "id": "Deprecated",
#       "message": "online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead."
#     }]
#   }
# }
# 04:05:12 INFO:Successfully finished _load_json_prompt for url: 'https://api.dataplatform.cloud.ibm.com/wx/v1-beta/prompts/ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4?space_id=566d4549-253a-489c-8173-d3a9c92bb027&prompt_id=ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4'
# 04:05:12 DEBUG:Response(GET https://api.dataplatform.cloud.ibm.com/wx/v1-beta/prompts/ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4?space_id=566d4549-253a-489c-8173-d3a9c92bb027&prompt_id=ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4): {"id":"ba4ce1ca-f7af-4544-8879-5c2a8e6a88e4","name":"Car rental review satisfaction analysis","description":"","created_at":1702583046657,"created_by":"IBMid-0600019M7F","last_updated_at":1702785305891,"last_updated_by":"iam-ServiceId-4e678d10-eb31-4193-9ec3-86c0313ab18d","resource_key":"b0d4dc3294a6621e6a57c31313fd8457d516229e590d12c60a771c122501e564","lock":{"locked":true,"locked_by":"IBMid-0600019M7F","lock_type":"governance"},"model_version":{"number":"0.0.3","tag":"50b02e75-ac80-4d3c-9616-c2cc3a6d3a07","description":""},"is_template":true,"prompt_variables":{"Review":{"default_value":"Agent was nasty"}},"task_ids":["classification"],"prompt":{"model_id":"ibm/granite-13b-instruct-v2","model_parameters":{"decoding_method":"greedy","max_new_tokens":20,"min_new_tokens":0,"random_seed":null,"stop_sequences":[],"temperature":0.7,"top_k":50,"top_p":1,"repetition_penalty":1},"data":{"instruction":"Determine if the customer was satisfied with the experience based on the comment. Return simple yes or no.","input_prefix":"Review:","output_prefix":"Satisfied","examples":[["I thought the representative handled the initial situation badly.  The company was out of cars, with none coming in that day.  Then the representative tried to find us a car at another franchise.  There they were successful.","no"],["The car rental agent was very helpful. He worked with us to get a bigger car for very little additional fees","yes"]]},"input":[["{Review}",""]]}}
# 04:05:15 INFO:Successfully finished generate for url: 'https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text?version=2023-12-05'
# 04:05:15 DEBUG:Response(POST https://us-south.ml.cloud.ibm.com/ml/v1-beta/deployments/22905dc9-3d72-427a-91d2-8e3ddbae8b3b/generation/text?version=2023-12-05): {"model_id":"ibm/granite-13b-instruct-v2","created_at":"2023-12-17T04:05:14.881Z","results":[{"generated_text":"no\n\n","generated_token_count":3,"input_token_count":117,"stop_reason":"eos_token"}]}
# 04:05:15 INFO:Generated text using model inference: no

# %% [markdown]
# ### Approach 3: Call inference endpoint using REST API

# %%
# Call inference endpoint using REST API
# Get an IAM token from IBM Cloud
url = "https://iam.cloud.ibm.com/identity/token"

headers={
    "Content-Type"  : "application/x-www-form-urlencoded",
    "cache-control" : "no-cache"
}

auth_data = f"grant_type=urn:ibm:params:oauth:grant-type:apikey&apikey={apikey}"

# Get access token
response = requests.post(url, data = auth_data, headers = headers, verify=True)

if response.status_code == 200:
    access_token = response.json()["access_token"]

    # Send payload to model inference
    request_headers = {"Content-Type"   : "application/json",
               "Authorization"  : "Bearer " + access_token}
    request_params = {"version": "2021-05-01"}
    
    inference_data={}
    inference_data['parameters'] = prompt_params
    logger.info(f"Inference payload : {inference_data}")
    
    response = requests.post(inference_url, data=json.dumps(inference_data), params=request_params, headers=request_headers)
    response_json = response.json()
    logger.debug(response_json)
    generated_text_using_rest_api = response_json['results'][0]['generated_text']
    logger.info(f"Generated text using REST API: {generated_text_using_rest_api}")
else:
    logger.error(response.text)
    logger.error(response.status_code)
    logger.error(response.reason)
# Out:
# 04:05:15 INFO:Inference payload : {'parameters': {'prompt_variables': {'Review': 'Agent was very nasty and rude'}}}
# 04:05:15 DEBUG:{'model_id': 'ibm/granite-13b-instruct-v2', 'created_at': '2023-12-17T04:05:15.662Z', 'results': [{'generated_text': 'no\n\n', 'generated_token_count': 3, 'input_token_count': 117, 'stop_reason': 'eos_token'}]}
# 04:05:15 INFO:Generated text using REST API: no

# %% [markdown]
# ### Authors
#
# **Shuvanker Ghosh (sghosh@us.ibm.com)** is a member of the Worldwide Data and AI Solution Engineering, IBM Technology Expert Labs.
